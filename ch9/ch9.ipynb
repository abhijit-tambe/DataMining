# %%
import os
import sys

# %%
data_folder = os.path.join(os.path.expanduser("~"),"Datamining","ch9", "Data", "books")

# %%
data_folder
# Out:
# 'C:\\Users\\abhijit\\Datamining\\ch9\\Data\\books'

# %%
import os
from time import sleep
import urllib.request

titles = {}


titles['burton'] = [4657, 2400, 5760, 6036, 7111, 8821,
                    18506, 4658, 5761, 6886, 7113]
titles['dickens'] = [24022, 1392, 1414, 1467, 2324, 580,
                     786, 888, 963, 27924, 1394, 1415, 15618,
                     25985, 588, 807, 914, 967, 30127, 1400,
                     1421, 16023, 28198, 644, 809, 917, 968, 1023,
                     1406, 1422, 17879, 30368, 675, 810, 924, 98,
                     1289, 1413, 1423, 17880, 32241, 699, 821, 927]
titles['doyle'] = [2349, 11656, 1644, 22357, 2347, 290, 34627, 5148,
                   8394, 26153, 12555, 1661, 23059, 2348, 294, 355,
                   5260, 8727, 10446, 126, 17398, 2343, 2350, 3070,
                   356, 5317, 903, 10581, 13152, 2038, 2344, 244, 32536,
                   423, 537, 108, 139, 2097, 2345, 24951, 32777, 4295,
                   7964, 11413, 1638, 21768, 2346, 2845, 3289, 439, 834]
titles['gaboriau'] = [1748, 1651, 2736, 3336, 4604, 4002, 2451,
                      305, 3802, 547]
titles['nesbit'] = [34219, 23661, 28804, 4378, 778, 20404, 28725,
                    33028, 4513, 794]
titles['tarkington'] = [1098, 15855, 1983, 297, 402, 5798,
                        8740, 980, 1158, 1611, 2326, 30092,
                        483, 5949, 8867, 13275, 18259, 2595,
                        3428, 5756, 6401, 9659]
titles['twain'] = [1044, 1213, 245, 30092, 3176, 3179, 3183, 3189, 74,
                   86, 1086, 142, 2572, 3173, 3177, 3180, 3186, 3192,
                   76, 91, 119, 1837, 2895, 3174, 3178, 3181, 3187, 3432,
                   8525]



assert len(titles) == 7

assert len(titles['tarkington']) == 22
assert len(titles['dickens']) == 44
assert len(titles['nesbit']) == 10
assert len(titles['doyle']) == 51
assert len(titles['twain']) == 29
assert len(titles['burton']) == 11
assert len(titles['gaboriau']) == 10


# https://www.gutenberg.org
#url_base = "http://gutenberg.pglaf.org/"
#url_base = "http://gutenberg.readingroo.ms/"
#url_base = "http://www.gutenberg.myebook.bg/"
url_base = 'http://www.gutenberg.org/'
#url_format = "{url_base}{idstring}/{id}/{id}.txt"
url_format = "{url_base}/files/{id}/{id}.txt"

fixes = {}
fixes[1044] = url_base + "1/0/4/1044/1044-0.txt"
fixes[5148] = url_base + "5/1/4/5148/5148-0.txt"
fixes[4657] = "https://archive.org/stream/personalnarrativ04657gut/pnpa110.txt"
fixes[1467] = "https://archive.org/stream/somechristmassto01467gut/cdscs10p_djvu.txt"

data_folder = 'books'

# Make parent folder if not exists
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

for author in titles:
    print("Downloading titles from {author}".format(author=author))
    # Make author's folder if not exists
    author_folder = os.path.join(data_folder, author)
    if not os.path.exists(author_folder):
        os.makedirs(author_folder)
    # Download each title to this folder
    for bookid in titles[author]:
        if bookid in fixes:
            print(" - Applying fix to book with id {id}".format(id=bookid))
            url =  fixes[bookid]
        else:
            print(" - Getting book with id {id}".format(id=bookid))
            idstring = "/".join([str(bookid)[i] for i in range(len(str(bookid))-1)])
            print(bookid, idstring)
            url = url_format.format(url_base=url_base, idstring=idstring, id=bookid)
        print(" - " + url)
        filename = os.path.join(author_folder, "{id}.txt".format(id=bookid))
        if os.path.exists(filename):
            print(" - File already exists, skipping")
        else:
            try:
                urllib.request.urlretrieve(url, filename)
                print("Download complete")
            except:
                print('** Exception while attempting to download! Probably a 404!')
            finally:
                sleep(30)
# Out:
# Downloading titles from dickens
#  - Getting book with id 24022
# 24022 2/4/0/2
#  - http://www.gutenberg.org//files/24022/24022.txt
# Download complete
#  - Getting book with id 1392
# 1392 1/3/9
#  - http://www.gutenberg.org//files/1392/1392.txt
# Download complete
#  - Getting book with id 1414
# 1414 1/4/1
#  - http://www.gutenberg.org//files/1414/1414.txt
# Download complete
#  - Applying fix to book with id 1467
#  - https://archive.org/stream/somechristmassto01467gut/cdscs10p_djvu.txt
# Download complete
#  - Getting book with id 2324
# 2324 2/3/2
#  - http://www.gutenberg.org//files/2324/2324.txt
# Download complete
#  - Getting book with id 580
# 580 5/8
#  - http://www.gutenberg.org//files/580/580.txt
# Download complete
#  - Getting book with id 786
# 786 7/8
#  - http://www.gutenberg.org//files/786/786.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 888
# 888 8/8
#  - http://www.gutenberg.org//files/888/888.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 963
# 963 9/6
#  - http://www.gutenberg.org//files/963/963.txt
# Download complete
#  - Getting book with id 27924
# 27924 2/7/9/2
#  - http://www.gutenberg.org//files/27924/27924.txt
# Download complete
#  - Getting book with id 1394
# 1394 1/3/9
#  - http://www.gutenberg.org//files/1394/1394.txt
# Download complete
#  - Getting book with id 1415
# 1415 1/4/1
#  - http://www.gutenberg.org//files/1415/1415.txt
# Download complete
#  - Getting book with id 15618
# 15618 1/5/6/1
#  - http://www.gutenberg.org//files/15618/15618.txt
# Download complete
#  - Getting book with id 25985
# 25985 2/5/9/8
#  - http://www.gutenberg.org//files/25985/25985.txt
# Download complete
#  - Getting book with id 588
# 588 5/8
#  - http://www.gutenberg.org//files/588/588.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 807
# 807 8/0
#  - http://www.gutenberg.org//files/807/807.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 914
# 914 9/1
#  - http://www.gutenberg.org//files/914/914.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 967
# 967 9/6
#  - http://www.gutenberg.org//files/967/967.txt
# Download complete
#  - Getting book with id 30127
# 30127 3/0/1/2
#  - http://www.gutenberg.org//files/30127/30127.txt
# Download complete
#  - Getting book with id 1400
# 1400 1/4/0
#  - http://www.gutenberg.org//files/1400/1400.txt
# Download complete
#  - Getting book with id 1421
# 1421 1/4/2
#  - http://www.gutenberg.org//files/1421/1421.txt
# Download complete
#  - Getting book with id 16023
# 16023 1/6/0/2
#  - http://www.gutenberg.org//files/16023/16023.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 28198
# 28198 2/8/1/9
#  - http://www.gutenberg.org//files/28198/28198.txt
# Download complete
#  - Getting book with id 644
# 644 6/4
#  - http://www.gutenberg.org//files/644/644.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 809
# 809 8/0
#  - http://www.gutenberg.org//files/809/809.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 917
# 917 9/1
#  - http://www.gutenberg.org//files/917/917.txt
# Download complete
#  - Getting book with id 968
# 968 9/6
#  - http://www.gutenberg.org//files/968/968.txt
# Download complete
#  - Getting book with id 1023
# 1023 1/0/2
#  - http://www.gutenberg.org//files/1023/1023.txt
# Download complete
#  - Getting book with id 1406
# 1406 1/4/0
#  - http://www.gutenberg.org//files/1406/1406.txt
# Download complete
#  - Getting book with id 1422
# 1422 1/4/2
#  - http://www.gutenberg.org//files/1422/1422.txt
# Download complete
#  - Getting book with id 17879
# 17879 1/7/8/7
#  - http://www.gutenberg.org//files/17879/17879.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 30368
# 30368 3/0/3/6
#  - http://www.gutenberg.org//files/30368/30368.txt
# Download complete
#  - Getting book with id 675
# 675 6/7
#  - http://www.gutenberg.org//files/675/675.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 810
# 810 8/1
#  - http://www.gutenberg.org//files/810/810.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 924
# 924 9/2
#  - http://www.gutenberg.org//files/924/924.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 98
# 98 9
#  - http://www.gutenberg.org//files/98/98.txt
# Download complete
#  - Getting book with id 1289
# 1289 1/2/8
#  - http://www.gutenberg.org//files/1289/1289.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 1413
# 1413 1/4/1
#  - http://www.gutenberg.org//files/1413/1413.txt
# Download complete
#  - Getting book with id 1423
# 1423 1/4/2
#  - http://www.gutenberg.org//files/1423/1423.txt
# Download complete
#  - Getting book with id 17880
# 17880 1/7/8/8
#  - http://www.gutenberg.org//files/17880/17880.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 32241
# 32241 3/2/2/4
#  - http://www.gutenberg.org//files/32241/32241.txt
# Download complete
#  - Getting book with id 699
# 699 6/9
#  - http://www.gutenberg.org//files/699/699.txt
# Download complete
#  - Getting book with id 821
# 821 8/2
#  - http://www.gutenberg.org//files/821/821.txt
# Download complete
#  - Getting book with id 927
# 927 9/2
#  - http://www.gutenberg.org//files/927/927.txt
# ** Exception while attempting to download! Probably a 404!
# Downloading titles from twain
#  - Applying fix to book with id 1044
#  - http://www.gutenberg.org/1/0/4/1044/1044-0.txt
# Download complete
#  - Getting book with id 1213
# 1213 1/2/1
#  - http://www.gutenberg.org//files/1213/1213.txt
# Download complete
#  - Getting book with id 245
# 245 2/4
#  - http://www.gutenberg.org//files/245/245.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 30092
# 30092 3/0/0/9
#  - http://www.gutenberg.org//files/30092/30092.txt
# Download complete
#  - Getting book with id 3176
# 3176 3/1/7
#  - http://www.gutenberg.org//files/3176/3176.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3179
# 3179 3/1/7
#  - http://www.gutenberg.org//files/3179/3179.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3183
# 3183 3/1/8
#  - http://www.gutenberg.org//files/3183/3183.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3189
# 3189 3/1/8
#  - http://www.gutenberg.org//files/3189/3189.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 74
# 74 7
#  - http://www.gutenberg.org//files/74/74.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 86
# 86 8
#  - http://www.gutenberg.org//files/86/86.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 1086
# 1086 1/0/8
#  - http://www.gutenberg.org//files/1086/1086.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 142
# 142 1/4
#  - http://www.gutenberg.org//files/142/142.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 2572
# 2572 2/5/7
#  - http://www.gutenberg.org//files/2572/2572.txt
# Download complete
#  - Getting book with id 3173
# 3173 3/1/7
#  - http://www.gutenberg.org//files/3173/3173.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3177
# 3177 3/1/7
#  - http://www.gutenberg.org//files/3177/3177.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3180
# 3180 3/1/8
#  - http://www.gutenberg.org//files/3180/3180.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3186
# 3186 3/1/8
#  - http://www.gutenberg.org//files/3186/3186.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3192
# 3192 3/1/9
#  - http://www.gutenberg.org//files/3192/3192.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 76
# 76 7
#  - http://www.gutenberg.org//files/76/76.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 91
# 91 9
#  - http://www.gutenberg.org//files/91/91.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 119
# 119 1/1
#  - http://www.gutenberg.org//files/119/119.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 1837
# 1837 1/8/3
#  - http://www.gutenberg.org//files/1837/1837.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 2895
# 2895 2/8/9
#  - http://www.gutenberg.org//files/2895/2895.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3174
# 3174 3/1/7
#  - http://www.gutenberg.org//files/3174/3174.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3178
# 3178 3/1/7
#  - http://www.gutenberg.org//files/3178/3178.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3181
# 3181 3/1/8
#  - http://www.gutenberg.org//files/3181/3181.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3187
# 3187 3/1/8
#  - http://www.gutenberg.org//files/3187/3187.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 3432
# 3432 3/4/3
#  - http://www.gutenberg.org//files/3432/3432.txt
# Download complete
#  - Getting book with id 8525
# 8525 8/5/2
#  - http://www.gutenberg.org//files/8525/8525.txt
# ** Exception while attempting to download! Probably a 404!
# Downloading titles from gaboriau
#  - Getting book with id 1748
# 1748 1/7/4
#  - http://www.gutenberg.org//files/1748/1748.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 1651
# 1651 1/6/5
#  - http://www.gutenberg.org//files/1651/1651.txt
# Download complete
#  - Getting book with id 2736
# 2736 2/7/3
#  - http://www.gutenberg.org//files/2736/2736.txt
# Download complete
#  - Getting book with id 3336
# 3336 3/3/3
#  - http://www.gutenberg.org//files/3336/3336.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 4604
# 4604 4/6/0
#  - http://www.gutenberg.org//files/4604/4604.txt
# Download complete
#  - Getting book with id 4002
# 4002 4/0/0
#  - http://www.gutenberg.org//files/4002/4002.txt
# Download complete
#  - Getting book with id 2451
# 2451 2/4/5
#  - http://www.gutenberg.org//files/2451/2451.txt
# Download complete
#  - Getting book with id 305
# 305 3/0
#  - http://www.gutenberg.org//files/305/305.txt
# Download complete
#  - Getting book with id 3802
# 3802 3/8/0
#  - http://www.gutenberg.org//files/3802/3802.txt
# Download complete
#  - Getting book with id 547
# 547 5/4
#  - http://www.gutenberg.org//files/547/547.txt
# Download complete
# Downloading titles from tarkington
#  - Getting book with id 1098
# 1098 1/0/9
#  - http://www.gutenberg.org//files/1098/1098.txt
# Download complete
#  - Getting book with id 15855
# 15855 1/5/8/5
#  - http://www.gutenberg.org//files/15855/15855.txt
# Download complete
#  - Getting book with id 1983
# 1983 1/9/8
#  - http://www.gutenberg.org//files/1983/1983.txt
# Download complete
#  - Getting book with id 297
# 297 2/9
#  - http://www.gutenberg.org//files/297/297.txt
# Download complete
#  - Getting book with id 402
# 402 4/0
#  - http://www.gutenberg.org//files/402/402.txt
# Download complete
#  - Getting book with id 5798
# 5798 5/7/9
#  - http://www.gutenberg.org//files/5798/5798.txt
# Download complete
#  - Getting book with id 8740
# 8740 8/7/4
#  - http://www.gutenberg.org//files/8740/8740.txt
# Download complete
#  - Getting book with id 980
# 980 9/8
#  - http://www.gutenberg.org//files/980/980.txt
# Download complete
#  - Getting book with id 1158
# 1158 1/1/5
#  - http://www.gutenberg.org//files/1158/1158.txt
# Download complete
#  - Getting book with id 1611
# 1611 1/6/1
#  - http://www.gutenberg.org//files/1611/1611.txt
# Download complete
#  - Getting book with id 2326
# 2326 2/3/2
#  - http://www.gutenberg.org//files/2326/2326.txt
# Download complete
#  - Getting book with id 30092
# 30092 3/0/0/9
#  - http://www.gutenberg.org//files/30092/30092.txt
# Download complete
#  - Getting book with id 483
# 483 4/8
#  - http://www.gutenberg.org//files/483/483.txt
# Download complete
#  - Getting book with id 5949
# 5949 5/9/4
#  - http://www.gutenberg.org//files/5949/5949.txt
# Download complete
#  - Getting book with id 8867
# 8867 8/8/6
#  - http://www.gutenberg.org//files/8867/8867.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 13275
# 13275 1/3/2/7
#  - http://www.gutenberg.org//files/13275/13275.txt
# Download complete
#  - Getting book with id 18259
# 18259 1/8/2/5
#  - http://www.gutenberg.org//files/18259/18259.txt
# Download complete
#  - Getting book with id 2595
# 2595 2/5/9
#  - http://www.gutenberg.org//files/2595/2595.txt
# Download complete
#  - Getting book with id 3428
# 3428 3/4/2
#  - http://www.gutenberg.org//files/3428/3428.txt
# Download complete
#  - Getting book with id 5756
# 5756 5/7/5
#  - http://www.gutenberg.org//files/5756/5756.txt
# Download complete
#  - Getting book with id 6401
# 6401 6/4/0
#  - http://www.gutenberg.org//files/6401/6401.txt
# Download complete
#  - Getting book with id 9659
# 9659 9/6/5
#  - http://www.gutenberg.org//files/9659/9659.txt
# Download complete
# Downloading titles from burton
#  - Applying fix to book with id 4657
#  - https://archive.org/stream/personalnarrativ04657gut/pnpa110.txt
# Download complete
#  - Getting book with id 2400
# 2400 2/4/0
#  - http://www.gutenberg.org//files/2400/2400.txt
# Download complete
#  - Getting book with id 5760
# 5760 5/7/6
#  - http://www.gutenberg.org//files/5760/5760.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 6036
# 6036 6/0/3
#  - http://www.gutenberg.org//files/6036/6036.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 7111
# 7111 7/1/1
#  - http://www.gutenberg.org//files/7111/7111.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 8821
# 8821 8/8/2
#  - http://www.gutenberg.org//files/8821/8821.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 18506
# 18506 1/8/5/0
#  - http://www.gutenberg.org//files/18506/18506.txt
# Download complete
#  - Getting book with id 4658
# 4658 4/6/5
#  - http://www.gutenberg.org//files/4658/4658.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 5761
# 5761 5/7/6
#  - http://www.gutenberg.org//files/5761/5761.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 6886
# 6886 6/8/8
#  - http://www.gutenberg.org//files/6886/6886.txt
# Download complete
#  - Getting book with id 7113
# 7113 7/1/1
#  - http://www.gutenberg.org//files/7113/7113.txt
# ** Exception while attempting to download! Probably a 404!
# Downloading titles from nesbit
#  - Getting book with id 34219
# 34219 3/4/2/1
#  - http://www.gutenberg.org//files/34219/34219.txt
# Download complete
#  - Getting book with id 23661
# 23661 2/3/6/6
#  - http://www.gutenberg.org//files/23661/23661.txt
# Download complete
#  - Getting book with id 28804
# 28804 2/8/8/0
#  - http://www.gutenberg.org//files/28804/28804.txt
# Download complete
#  - Getting book with id 4378
# 4378 4/3/7
#  - http://www.gutenberg.org//files/4378/4378.txt
# Download complete
#  - Getting book with id 778
# 778 7/7
#  - http://www.gutenberg.org//files/778/778.txt
# Download complete
#  - Getting book with id 20404
# 20404 2/0/4/0
#  - http://www.gutenberg.org//files/20404/20404.txt
# Download complete
#  - Getting book with id 28725
# 28725 2/8/7/2
#  - http://www.gutenberg.org//files/28725/28725.txt
# Download complete
#  - Getting book with id 33028
# 33028 3/3/0/2
#  - http://www.gutenberg.org//files/33028/33028.txt
# Download complete
#  - Getting book with id 4513
# 4513 4/5/1
#  - http://www.gutenberg.org//files/4513/4513.txt
# Download complete
#  - Getting book with id 794
# 794 7/9
#  - http://www.gutenberg.org//files/794/794.txt
# ** Exception while attempting to download! Probably a 404!
# Downloading titles from doyle
#  - Getting book with id 2349
# 2349 2/3/4
#  - http://www.gutenberg.org//files/2349/2349.txt
# Download complete
#  - Getting book with id 11656
# 11656 1/1/6/5
#  - http://www.gutenberg.org//files/11656/11656.txt
# Download complete
#  - Getting book with id 1644
# 1644 1/6/4
#  - http://www.gutenberg.org//files/1644/1644.txt
# Download complete
#  - Getting book with id 22357
# 22357 2/2/3/5
#  - http://www.gutenberg.org//files/22357/22357.txt
# Download complete
#  - Getting book with id 2347
# 2347 2/3/4
#  - http://www.gutenberg.org//files/2347/2347.txt
# Download complete
#  - Getting book with id 290
# 290 2/9
#  - http://www.gutenberg.org//files/290/290.txt
# Download complete
#  - Getting book with id 34627
# 34627 3/4/6/2
#  - http://www.gutenberg.org//files/34627/34627.txt
# Download complete
#  - Applying fix to book with id 5148
#  - http://www.gutenberg.org/5/1/4/5148/5148-0.txt
# Download complete
#  - Getting book with id 8394
# 8394 8/3/9
#  - http://www.gutenberg.org//files/8394/8394.txt
# Download complete
#  - Getting book with id 26153
# 26153 2/6/1/5
#  - http://www.gutenberg.org//files/26153/26153.txt
# Download complete
#  - Getting book with id 12555
# 12555 1/2/5/5
#  - http://www.gutenberg.org//files/12555/12555.txt
# Download complete
#  - Getting book with id 1661
# 1661 1/6/6
#  - http://www.gutenberg.org//files/1661/1661.txt
# Download complete
#  - Getting book with id 23059
# 23059 2/3/0/5
#  - http://www.gutenberg.org//files/23059/23059.txt
# Download complete
#  - Getting book with id 2348
# 2348 2/3/4
#  - http://www.gutenberg.org//files/2348/2348.txt
# Download complete
#  - Getting book with id 294
# 294 2/9
#  - http://www.gutenberg.org//files/294/294.txt
# Download complete
#  - Getting book with id 355
# 355 3/5
#  - http://www.gutenberg.org//files/355/355.txt
# Download complete
#  - Getting book with id 5260
# 5260 5/2/6
#  - http://www.gutenberg.org//files/5260/5260.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 8727
# 8727 8/7/2
#  - http://www.gutenberg.org//files/8727/8727.txt
# Download complete
#  - Getting book with id 10446
# 10446 1/0/4/4
#  - http://www.gutenberg.org//files/10446/10446.txt
# Download complete
#  - Getting book with id 126
# 126 1/2
#  - http://www.gutenberg.org//files/126/126.txt
# Download complete
#  - Getting book with id 17398
# 17398 1/7/3/9
#  - http://www.gutenberg.org//files/17398/17398.txt
# Download complete
#  - Getting book with id 2343
# 2343 2/3/4
#  - http://www.gutenberg.org//files/2343/2343.txt
# Download complete
#  - Getting book with id 2350
# 2350 2/3/5
#  - http://www.gutenberg.org//files/2350/2350.txt
# Download complete
#  - Getting book with id 3070
# 3070 3/0/7
#  - http://www.gutenberg.org//files/3070/3070.txt
# Download complete
#  - Getting book with id 356
# 356 3/5
#  - http://www.gutenberg.org//files/356/356.txt
# Download complete
#  - Getting book with id 5317
# 5317 5/3/1
#  - http://www.gutenberg.org//files/5317/5317.txt
# Download complete
#  - Getting book with id 903
# 903 9/0
#  - http://www.gutenberg.org//files/903/903.txt
# Download complete
#  - Getting book with id 10581
# 10581 1/0/5/8
#  - http://www.gutenberg.org//files/10581/10581.txt
# Download complete
#  - Getting book with id 13152
# 13152 1/3/1/5
#  - http://www.gutenberg.org//files/13152/13152.txt
# Download complete
#  - Getting book with id 2038
# 2038 2/0/3
#  - http://www.gutenberg.org//files/2038/2038.txt
# Download complete
#  - Getting book with id 2344
# 2344 2/3/4
#  - http://www.gutenberg.org//files/2344/2344.txt
# Download complete
#  - Getting book with id 244
# 244 2/4
#  - http://www.gutenberg.org//files/244/244.txt
# Download complete
#  - Getting book with id 32536
# 32536 3/2/5/3
#  - http://www.gutenberg.org//files/32536/32536.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 423
# 423 4/2
#  - http://www.gutenberg.org//files/423/423.txt
# Download complete
#  - Getting book with id 537
# 537 5/3
#  - http://www.gutenberg.org//files/537/537.txt
# Download complete
#  - Getting book with id 108
# 108 1/0
#  - http://www.gutenberg.org//files/108/108.txt
# Download complete
#  - Getting book with id 139
# 139 1/3
#  - http://www.gutenberg.org//files/139/139.txt
# Download complete
#  - Getting book with id 2097
# 2097 2/0/9
#  - http://www.gutenberg.org//files/2097/2097.txt
# Download complete
#  - Getting book with id 2345
# 2345 2/3/4
#  - http://www.gutenberg.org//files/2345/2345.txt
# Download complete
#  - Getting book with id 24951
# 24951 2/4/9/5
#  - http://www.gutenberg.org//files/24951/24951.txt
# Download complete
#  - Getting book with id 32777
# 32777 3/2/7/7
#  - http://www.gutenberg.org//files/32777/32777.txt
# Download complete
#  - Getting book with id 4295
# 4295 4/2/9
#  - http://www.gutenberg.org//files/4295/4295.txt
# ** Exception while attempting to download! Probably a 404!
#  - Getting book with id 7964
# 7964 7/9/6
#  - http://www.gutenberg.org//files/7964/7964.txt
# Download complete
#  - Getting book with id 11413
# 11413 1/1/4/1
#  - http://www.gutenberg.org//files/11413/11413.txt
# Download complete
#  - Getting book with id 1638
# 1638 1/6/3
#  - http://www.gutenberg.org//files/1638/1638.txt
# Download complete
#  - Getting book with id 21768
# 21768 2/1/7/6
#  - http://www.gutenberg.org//files/21768/21768.txt
# Download complete
#  - Getting book with id 2346
# 2346 2/3/4
#  - http://www.gutenberg.org//files/2346/2346.txt
# Download complete
#  - Getting book with id 2845
# 2845 2/8/4
#  - http://www.gutenberg.org//files/2845/2845.txt
# Download complete
#  - Getting book with id 3289
# 3289 3/2/8
#  - http://www.gutenberg.org//files/3289/3289.txt
# Download complete
#  - Getting book with id 439
# 439 4/3
#  - http://www.gutenberg.org//files/439/439.txt
# Download complete
#  - Getting book with id 834
# 834 8/3
#  - http://www.gutenberg.org//files/834/834.txt
# Download complete

# %%
def clean_book(document):
    lines = document.split("n")
    start= 0
    end = len(lines)
    for i in range(len(lines)):
        line = lines[i]
        if line.startswith("*** START OF THIS PROJECT GUTENBERG"):
            start = i + 1
        elif line.startswith("*** END OF  THIS PROJECT GUTENBERG"):
            end = i - 1
    return "n".join(lines[start:end])

# %%
import numpy as np
def load_books_data(folder=data_folder):
    documents = []
    authors = []
    subfolders = [subfolder for subfolder in os.listdir(folder)
                  if os.path.isdir(os.path.join(folder, subfolder))]
    for author_number, subfolder in enumerate(subfolders):
        full_subfolder_path = os.path.join(folder, subfolder)
        for document_name in os.listdir(full_subfolder_path):
            with open(os.path.join(full_subfolder_path, document_name), encoding="ISO-8859-1") as inf:
                documents.append(clean_book(inf.read()))
                authors.append(author_number)
    return documents, np.array(authors, dtype='int')

# %%
documents,  classes = load_books_data(data_folder)

# %%
# %matplotlib inline

# %%
document_lengths = [len(document) for document in documents]

# %%
import seaborn as sns
sns.distplot(document_lengths)
# Out:
# E:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-121717bdba90> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.distplot(document_lengths)
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     281         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     282                                            gridsize, cut, clip,
# --> 283                                            cumulative=cumulative)
#     284     else:
#     285         # Fall back to scipy if missing statsmodels
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     353     fft = kernel == "gau"
#     354     kde = smnp.KDEUnivariate(data)
# --> 355     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     356     if cumulative:
#     357         grid, y = kde.support, kde.cdf
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
function_words = ["a", "able", "aboard", "about", "above", "absent",
                  "according" , "accordingly", "across", "after", "against",
                  "ahead", "albeit", "all", "along", "alongside", "although",
                  "am", "amid", "amidst", "among", "amongst", "amount", "an",
                    "and", "another", "anti", "any", "anybody", "anyone",
                    "anything", "are", "around", "as", "aside", "astraddle",
                    "astride", "at", "away", "bar", "barring", "be", "because",
                    "been", "before", "behind", "being", "below", "beneath",
                    "beside", "besides", "better", "between", "beyond", "bit",
                    "both", "but", "by", "can", "certain", "circa", "close",
                    "concerning", "consequently", "considering", "could",
                    "couple", "dare", "deal", "despite", "down", "due", "during",
                    "each", "eight", "eighth", "either", "enough", "every",
                    "everybody", "everyone", "everything", "except", "excepting",
                    "excluding", "failing", "few", "fewer", "fifth", "first",
                    "five", "following", "for", "four", "fourth", "from", "front",
                    "given", "good", "great", "had", "half", "have", "he",
                    "heaps", "hence", "her", "hers", "herself", "him", "himself",
                    "his", "however", "i", "if", "in", "including", "inside",
                    "instead", "into", "is", "it", "its", "itself", "keeping",
                    "lack", "less", "like", "little", "loads", "lots", "majority",
                    "many", "masses", "may", "me", "might", "mine", "minority",
                    "minus", "more", "most", "much", "must", "my", "myself",
                    "near", "need", "neither", "nevertheless", "next", "nine",
                    "ninth", "no", "nobody", "none", "nor", "nothing",
                    "notwithstanding", "number", "numbers", "of", "off", "on",
                    "once", "one", "onto", "opposite", "or", "other", "ought",
                    "our", "ours", "ourselves", "out", "outside", "over", "part",
                    "past", "pending", "per", "pertaining", "place", "plenty",
                    "plethora", "plus", "quantities", "quantity", "quarter",
                    "regarding", "remainder", "respecting", "rest", "round",
                    "save", "saving", "second", "seven", "seventh", "several",
                    "shall", "she", "should", "similar", "since", "six", "sixth",
                    "so", "some", "somebody", "someone", "something", "spite",
                    "such", "ten", "tenth", "than", "thanks", "that", "the",
                    "their", "theirs", "them", "themselves", "then", "thence",
                  "therefore", "these", "they", "third", "this", "those",
"though", "three", "through", "throughout", "thru", "thus",
"till", "time", "to", "tons", "top", "toward", "towards",
"two", "under", "underneath", "unless", "unlike", "until",
"unto", "up", "upon", "us", "used", "various", "versus",
"via", "view", "wanting", "was", "we", "were", "what",
"whatever", "when", "whenever", "where", "whereas",
"wherever", "whether", "which", "whichever", "while",
                  "whilst", "who", "whoever", "whole", "whom", "whomever",
"whose", "will", "with", "within", "without", "would", "yet",
"you", "your", "yours", "yourself", "yourselves"]

# %%
from sklearn.feature_extraction.text import CountVectorizer 
extractor = CountVectorizer(vocabulary=function_words)

# %%
extractor.fit(documents) 
counts = extractor.transform(documents)

# %%
normalized_counts = counts.T / np.array(document_lengths)

# %%
averaged_counts = normalized_counts.mean(axis=1)

# %%
from matplotlib import pyplot as plt 
plt.plot(averaged_counts)

# %%
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.pipeline import Pipeline from sklearn import grid_search
# Out:
#   File "<ipython-input-26-b15254403197>", line 3
#     from sklearn.pipeline import Pipeline from sklearn import grid_search
#                                              ^
# SyntaxError: invalid syntax

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svr = SVC(gamma='auto')
grid = GridSearchCV(svr, parameters, cv=3)

# %%
pipeline1 = Pipeline([('feature_extraction', extractor), ('clf', grid) ])

# %%
pipeline = Pipeline([('feature_extraction', CountVectorizer(analyzer='char', ngram_range=(3, 3))),
                     ('classifier', grid)
                    ])
scores = cross_val_score(pipeline, documents, classes, scoring='f1_macro')
print("Score: {:.3f}".format(np.mean(scores)))
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:626: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# E:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# E:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Score: 0.624

# %%
enron_data_folder = os.path.join(os.path.expanduser("~"),"Datamining","ch9", "Data", "enron_mail_20150507", "maildir")

# %%
from email.parser import Parser 
p = Parser()

# %%
from sklearn.utils import check_random_state

# %%
def get_enron_corpus(num_authors=10, data_folder=enron_data_folder,
                     min_docs_author=10, max_docs_author=100,
                     random_state=None):
    random_state = check_random_state(random_state)
    email_addresses = sorted(os.listdir(data_folder))
    random_state.shuffle(email_addresses)
    documents = []
    classes = []
    author_num = 0
    authors = {}
    for user in email_addresses:
        users_email_folder = os.path.join(data_folder, user)
        mail_folders = [os.path.join(users_email_folder, subfolder)
                        for subfolder in os.listdir(users_email_folder)
                        if "sent" in subfolder]
        try:
            authored_emails = [open(os.path.join(mail_folder, email_filename), encoding='cp1252').read()
                               for mail_folder in mail_folders
                               for email_filename in os.listdir(mail_folder)]
        except IsADirectoryError:
            continue
        if len(authored_emails) < min_docs_author:
            continue
        if len(authored_emails) > max_docs_author:
            authored_emails = authored_emails[:max_docs_author]
        contents = [p.parsestr(email)._payload for email in authored_emails]
        documents.extend(contents)
        classes.extend([author_num] * len(authored_emails))
        authors[user] = author_num
        author_num += 1
        if author_num >= num_authors or author_num >= len(email_addresses):
            break
    return documents, np.array(classes), authors

# %%
documents, classes, authors = get_enron_corpus(data_folder=enron_data_folder, random_state=14)

# %%
document_lengths = [len(document) for document in documents]
sns.distplot(document_lengths)
# Out:
# E:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-a478c3060a4f> in <module>()
#       1 document_lengths = [len(document) for document in documents]
# ----> 2 sns.distplot(document_lengths)
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     281         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     282                                            gridsize, cut, clip,
# --> 283                                            cumulative=cumulative)
#     284     else:
#     285         # Fall back to scipy if missing statsmodels
#
# E:\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     353     fft = kernel == "gau"
#     354     kde = smnp.KDEUnivariate(data)
# --> 355     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     356     if cumulative:
#     357         grid, y = kde.support, kde.cdf
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# E:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
scores = cross_val_score(pipeline, documents, classes, scoring='f1_macro')
print("Score: {:.3f}".format(np.mean(scores)))
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# E:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Score: 0.599

# %%
from sklearn.model_selection import train_test_split
training_documents, testing_documents, y_train, y_test = train_test_split(documents, classes, random_state=14)

# %%
pipeline.fit(training_documents, y_train)
y_pred = pipeline.predict(testing_documents)

# %%
print(pipeline.named_steps['classifier'].best_params_)
# Out:
# {'kernel': 'linear', 'C': 1}

# %%
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_pred, y_test) 
cm = cm / cm.astype(np.float).sum(axis=1)

# %%
sorted_authors = sorted(authors.keys(), key=lambda x:authors[x])

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.figure(figsize=(30, 30))
plt.imshow(cm, cmap='Blues', interpolation='nearest')
tick_marks = np.arange(len( sorted_authors ))
plt.xticks(tick_marks, sorted_authors )
plt.yticks(tick_marks, sorted_authors )
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
